# %% [markdown]
# # Hate Speech/ Offensive Language Detection

# %%
import pandas as pd
import numpy as np
import seaborn
import string
import pickle
import re
import sys, codecs
#print sys.path
import nltk
from nltk.stem.porter import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer as VS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt
# %matplotlib inline
nltk.download('stopwords')
#!pip install textstat
#get_ipython().system(u'pip install repoze.lru')
##import textstat
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Loading the data

# %%
from google.colab import files
uploaded = files.upload()
import io

df = pd.read_csv(io.StringIO(uploaded['labeled_data.csv'].decode('utf-8')))
df
# Out:
#      <input type="file" id="files-7e318653-a488-4a09-9730-6038f3cd769e" name="files[]" multiple disabled />
#      <output id="result-7e318653-a488-4a09-9730-6038f3cd769e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labeled_data.csv to labeled_data (1).csv
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-22-67b3ebd6699f> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#       3 import io
#       4
#       5 df = pd.read_csv(io.StringIO(uploaded['labeled_data.csv'].decode('utf-8')))
#
# /usr/local/lib/python2.7/dist-packages/google/colab/files.pyc in upload()
#      70     result = _output.eval_js(
#      71         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 72             output_id=output_id))
#      73     if result['action'] != 'append':
#      74       # JS side uses a generator of promises to process all of the files- some
#
# /usr/local/lib/python2.7/dist-packages/google/colab/output/_js.pyc in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python2.7/dist-packages/google/colab/_message.pyc in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# Description of data

# %%
df.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %% [markdown]
# df.columns

# %% [markdown]
# Columns key:
# count = number of CrowdFlower users who coded each tweet (min is 3, sometimes more users coded a tweet when judgments were determined to be unreliable by CF).
#
# hate_speech = number of CF users who judged the tweet to be hate speech.
#
# offensive_language = number of CF users who judged the tweet to be offensive.
#
# neither = number of CF users who judged the tweet to be neither offensive nor non-offensive.
#
# class = class label for majority of CF users.
#
# 0 - hate speech
# 1 - offensive  language
# 2 - neither
# tweet = raw tweet text

# %%
df['class'].hist()

# %% [markdown]
# This histogram shows the imbalanced nature of the task - most tweets containing "hate" words as defined by Hatebase were
# only considered to be offensive by the CF coders. More tweets were considered to be neither hate speech nor offensive language than were considered hate speech.

# %%
tweets=df.tweet

# %% [markdown]
# ## Feature generation

# %%
stopwords=stopwords = nltk.corpus.stopwords.words("english")

other_exclusions = ["#ff", "ff", "rt"]
stopwords.extend(other_exclusions)

stemmer = PorterStemmer()


def preprocess(text_string):
    """
    Accepts a text string and replaces:
    1) urls with URLHERE
    2) lots of whitespace with one instance
    3) mentions with MENTIONHERE

    This allows us to get standardized counts of urls and mentions
    Without caring about specific people mentioned
    """
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, '', parsed_text)
    parsed_text = re.sub(mention_regex, '', parsed_text)
    return parsed_text

def tokenize(tweet):
    """Removes punctuation & excess whitespace, sets to lowercase,
    and stems tweets. Returns a list of stemmed tokens."""
    tweet = " ".join(re.split("[^a-zA-Z]*", tweet.lower())).strip()
    tokens = [stemmer.stem(t) for t in tweet.split()]
    return tokens

def basic_tokenize(tweet):
    """Same as tokenize but without the stemming"""
    tweet = " ".join(re.split("[^a-zA-Z.,!?]*", tweet.lower())).strip()
    return tweet.split()

vectorizer = TfidfVectorizer(
    tokenizer=tokenize,
    preprocessor=preprocess,
    ngram_range=(1, 3),
    stop_words=stopwords,
    use_idf=True,
    smooth_idf=False,
    norm=None,
    decode_error='replace',
    max_features=10000,
    min_df=5,
    max_df=0.75
    )

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Construct tfidf matrix and get relevant scores
tfidf = vectorizer.fit_transform(tweets).toarray()
vocab = {v:i for i, v in enumerate(vectorizer.get_feature_names())}
idf_vals = vectorizer.idf_
idf_dict = {i:idf_vals[i] for i in vocab.values()} #keys are indices; values are IDF scores
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [u'abov', u'ani', u'becaus', u'befor', u'doe', u'dure', u'ha', u'hi', u'onc', u'onli', u'ourselv', u'themselv', u'thi', u'veri', u'wa', u'whi', u'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
#packjs=['sentiwordnet','unicode_samples','wordnet','vader_lexicon',
#        'words','rslp','subjectivity','word2vec_sample',
#        'maxent_ne_chunker','tagsets','universal_tagset','averaged_perceptron_tagger']
#tried:( packjs=['vadersentiment','maxent_treebank_pos']
nltk.download('vader_lexicon','tagsets','universal_tagset','averaged_perceptron_tagger')
#for i in packjs:
#   nltk.download(i)
# Out:
# True

# %%
#Get POS tags for tweets and save as a string
tweet_tags = []
for t in tweets:
    tokens = basic_tokenize(preprocess(t))
    tags = nltk.pos_tag(tokens)
    tag_list = [x[1] for x in tags]
    tag_str = " ".join(tag_list)
    tweet_tags.append(tag_str)

# %%
tweet_tags
# Out:
# ['RB NN IN DT NN PRP VBP JJ NN IN VBG RP PRP$ NN NN IN DT NN PRP MD RB VB DT NN NN',
#  'JJ NN NN NNS VBP JJ JJ IN NN NN NN IN DT NN NN',
#  'JJ NN NN NN PRP RB VBD DT NN CC PRP VBP TO VB PRP VB VBN IN NN',
#  'NN VBZ PRP VBP IN DT NN',
#  'NN VBZ DT NN PRP VBP IN PRP MD VB JJ CC PRP MD VB JJR IN DT NN WP VBD PRP TO VB',
#  'IN DT NN RB VBZ NN PRP RB JJ CC RB IN NN CC RB VBG IN NN',
#  'NN NN MD RB RB VB RP CC VB IN DT NN NN NN VBD RB JJ NN VBG NN',
#  'NN NN NN VBP VBN IN PRP JJ NNS VBG IN PRP VBP NNS',
#  'NN PRP MD RB VB JJ VB RB JJ NNS WDT',
#  'NNS VBP VBG NNS NN',
#  'NN VBZ DT NN PRP VBZ NN NN NN VBD IN DT NN IN NN NN',
#  'NN NN VB PRP$ NN NN',
#  'RB VBZ IN NN VBP NNS . NN : VBP IN NN',
#  'JJ NNS VBZ DT JJ NN IN NN IN',
#  'NN VB RP IN PRP',
#  'NN NN VB PRP IN PRP',
#  'NN NN WDT',
#  'NN WP VBP PRP VB',
#  'NNS VBP VBN RP JJ NN',
#  'JJ NN VBD DT JJ NN',
#  'VBD NN NN VB PRP NN',
#  'NN WDT VBP IN NN',
#  'NN PRP VBP DT NNS VBP NN',
#  'NN DT WDT VBP VB RB JJ VBP DT NN NN NN TO VB VB RP',
#  'VBD PRP VB NN VBG IN PRP$ NN NNS',
#  'PRP$ JJ NNS IN NN NNS',
#  'VB WP PRP$ NN IN',
#  'NN VBD IN NN IN JJ NN . NN VBD IN NN DT NN',
#  'NNS VBP DT JJ NN WP VBP IN NN',
#  'JJ VBP PRP$ NN WRB NN VBP NN PRP$ PRP$ NN',
#  'NN VBP PRP$ JJ NN PRP$ JJ NN NN NN',
#  'JJ NNS VBP JJ RB TO DT JJ PRP CC PRP$ JJ NNS MD VB JJ',
#  'IN PRP VBP IN DT NN NN JJ NN VBD RP',
#  'IN PRP VBP NNS VB RB VBN PRP VBP NNS',
#  'NN VBN IN JJ NNS PRP$ DT NN IN DT . IN PRP DT JJ NN VBZ DT NN IN DT',
#  'VBZ IN NN NN',
#  'PRP VBZ NN TO VB DT NN IN',
#  'NN NN NN RB PRP MD VB NN NNS NNS',
#  'NNS VBG IN NNS NNS NNS IN DT NN',
#  'IN NN VBD IN PRP VBP IN DT NNS',
#  'NN VBD DT NN VBZ IN PRP$ NN',
#  'RBS VBN CC DT NNS JJ NNS NN',
#  'JJ NNS VBP VB PRP VB JJ JJ NN NN JJ JJ NN RP RB JJ IN JJ JJ NN',
#  'NNS RP NNS RB NNS RP JJ NN',
#  'NN DT NN IN DT JJ NN NNS',
#  'NN VBZ DT JJ NN NN',
#  'JJ NN IN NN NN PRP DT NN IN',
#  'VBG NN RB IN DT NN JJ JJ NNS VBP TO VB JJ',
#  'DT NNS RB VBP PRP VBP VB PRP NNS IN PRP',
#  'DT NNS IN NN WDT VBP NN RB VB IN PRP',
#  'PRP VBP JJ DT IN PDT DT NNS',
#  'NN NN NN NN NNS VB DT NN RB VBP NNS',
#  'PRP VBP DT NN DT VBP NNS JJ VBD RP JJ CC VBN TO VB JJ NN',
#  'JJ NN VB DT NNS VBP PRP$ NN',
#  'NN NN RB JJR IN JJS IN DT NN NNS VB',
#  'NN NN NN NN NN TO VB IN NNS VBD',
#  'CC VB VB PRP$ NN RB VB PRP IN DT NN NN PRP DT NN PRP MD VB PRP',
#  'NN PRP VBZ VBN RB VB DT NN',
#  'NN IN DT NN VBD PRP$ JJ NN NN IN DT NN',
#  'NN NN VBP VBP VBZ VB NN CC JJ NN NN NN NNS',
#  'NN RB VBD JJ NN NN IN JJ IN PRP VBP NNS VBP TO VB IN NN NN NNS . NN',
#  'NN VBP DT VBG NN PRP VBD',
#  'NNS VBP VBG DT NN VBZ JJ JJ WRB VBZ VBG DT JJ VBP PRP DT NN',
#  'NNS VBP JJ JJ RB JJ',
#  'VB VBN RB VBN PRP$ NN IN JJ NNS JJ NN NNS',
#  'WRB JJ VBN JJ JJ NN NN TO DT NN WRB PRP VBP PRP JJ NNS IN NN NN VBP',
#  'NN NN CC JJ NNS',
#  'RB VB DT NN NN VBP DT VB CD NN NN',
#  'NN NN JJ RB PRP VBP VB NN RB',
#  'NN JJ NN NN NN NN NN MD PRP VB VB JJ NN',
#  'WRB DT NN NN NN NN PRP VBZ PRP VBD IN NN NN',
#  'NN NN NN WDT VBZ CD NN NN',
#  'PRP VB PRP JJ NN RB DT NN NN NN NN NN',
#  'NN CC DT NNS VBP TO VB IN NN NN RB VBN IN DT NN RB VBD DT RBS JJ NN',
#  'JJ NN NN DT VBP DT DT NN VBG NNS VBP NN VBZ NN',
#  'NN NN NN NN DT VBZ JJ NN',
#  'NN VBP NN NN . NN JJ NN',
#  'JJ RB VB DT NN IN DT NN CC VB VB WP IN DT NN VBD IN PRP$ NN TO VB DT JJ DT NN MD VB NN NN',
#  'NNS VBP NNS VBP',
#  'NN NN JJ IN DT NN NN : CC IN DT NN VBG RP DT NN VBD NN .',
#  'DT NNS IN NN PRP VBZ DT NN IN RB VBG PRP NNS',
#  'NN NNS VB VBG TO VB IN NNS RB JJ IN JJ NN NN CC JJ NN IN NN',
#  'VB VBG JJ NN NN',
#  'NN NN NN VBP NN VBP DT JJ NN NN PRP VBD DT NN',
#  'NN NN PRP VBZ RB VB DT NN NN VBZ PRP VBZ VBP TO VB PRP WRB PRP VBZ IN PRP$',
#  'NN NN',
#  'RB VB PRP$ NNS IN NN NN PRP VBZ JJ RB VBP NNS',
#  'DT NN VBD RB JJ NN NN NN',
#  'RB VBN VBN CD NN',
#  'NN VBZ DT NN NN PRP MD VB VB DT JJ',
#  'JJ NN NNS NNS VBP',
#  'WRB JJ NN NNS VBP IN NNS VBP VBN DT NN NN TO VB',
#  'DT NN VBD VBG IN NN NN NN RB JJ NN NN NN VBD NN NN',
#  'WP MD VB DT JJ RB VBP VBN NNS VBP IN PRP VBP VBG VBP RP JJ NN',
#  'RB RB VB DT JJ NN IN JJ MD VB NN CC VB NN PRP JJR VB VBG PRP$ NN',
#  'VBG RB TO NN NNS RBR JJ IN DT NNS WP VBP NN',
#  'IN PRP$ NN TO VB JJ VB PRP IN DT NN JJ',
#  'WRB VB PRP RB VB PRP NN NN VBP VBP DT NN NN',
#  'IN JJ VBP NN NN RP IN NN NN NNS VBZ RB PRP$ NN RB NN JJ VBD IN IN NN',
#  'WRB IN PRP VBP JJ NN',
#  'NN DT JJ JJ NN VBP NNS IN DT JJ NN',
#  "NN PRP VBP '' VBD VBG IN NN NN TO PRP IN PRP VBD VBG JJ NN NN",
#  'VB PRP VB DT JJ NNS RP JJ NN IN JJ VBD JJ NN IN NN NN NN NN NN NN IN PRP RB',
#  'NNS VBP VBZ RB DT NN TO VB JJ NN IN NN',
#  'NNS VBP NN CC PRP VBZ JJ NN TO VB IN DT NN RB VB PRP PRP RB VBD NN',
#  'NN NNS VBP DT WP JJ NN VBG DT NN NN NN',
#  'VBZ VBN VBN TO VB VBN PRP VBP RB',
#  'CD VBZ NN VBZ DT NNS NN',
#  'JJ VBP JJ VBD DT NN JJ NNS VBZ DT JJ NN NN IN NN',
#  'NN NN , DT NN VBZ PRP JJ VBP PRP VBZ VB RBR PRP$ JJ DT NN',
#  'NN NNS , NN NN JJ NNS , NN',
#  'PRP$ PRP VB PRP$ PRP NN NN',
#  'IN NN PRP VBP PRP NN IN NN PRP VBP PRP VB DT IN NN PRP VBP VBN VBN IN DT NN',
#  'JJ VBP JJ NN IN NN IN DT NN NN DT PRP VBD JJ NN NN NN',
#  'NN WRB NNS VBP CC VBP PRP IN DT JJ NN NN VBP NN TO VB VB PRP IN DT NN NN NN NN',
#  'NN JJ VBZ VBN TO VB DT NN NN VBD IN PRP$ NN NN NN',
#  'VB DT JJ NN NN NN VBD DT NN NN NN',
#  'VB PRP IN DT NN NN NN NN',
#  'UH PRP$ NN NN VBP NN NN DT PRP$ NNS IN PRP',
#  'IN JJ NN VBD NN NN VBD DT NN VBD VBG JJ NN',
#  'PRP VBZ VBG PRP JJ DT NNS VBP',
#  'PRP VBP JJ NN IN NN NN PRP VBZ NN . CC NN NN',
#  'NNS VBP JJ CC NNS VBP JJ CC NNS VBP IN PRP VBP IN NN NN',
#  'VBG IN PRP$ NN NN NN JJ NN NNS TO VB JJ VBN NN NNS',
#  'CC DT JJ NN VB DT JJ VB DT NN PRP VBP RB VBN',
#  'DT NN DT JJ NNS MD RB VB RB VBP PDT DT NN',
#  'NNS VBP RB RB VB NN FW NN NN NN NN VBZ NNS NN IN NN',
#  'NN NN VBD VBN IN DT NN PRP VBD IN IN DT NN CC PRP RB VBD RBR NNS IN PRP IN NN NN',
#  'NN VBZ DT NN NN NNS NNS NN',
#  'JJ JJ NN JJ NN NN',
#  'NN NN NN NN NN VBZ VBN IN NN NN',
#  'PRP MD VB PRP JJ NN NN VBP DT NNS VBP',
#  'NN MD RB VB DT NN IN DT JJ NN NNS VBP JJ VBD DT NN IN DT JJ NN IN PRP$ NN',
#  'NN NNS VBP TO VB IN PRP IN PRP VBP DT NN CC RB VBD DT NN IN JJ NN WRB NNS VBP IN',
#  'CC VBD NN IN JJ JJ NNS RB VBP WP PRP VBP IN PRP VBP JJ JJ NN VBP IN PRP VBP VBP PRP VBP',
#  'NN NN NN',
#  'PRP$ JJ JJ IN NN NN',
#  'WRB NN NNS VBP PRP PRP$ JJ NNS',
#  'JJ NNS IN PRP',
#  'RB DT NN VBZ IN DT NN NN',
#  'NN VBP IN JJ NN VBG TO PRP VB NN',
#  'PRP VBP VB VBG TO VB JJ NN PRP VBP JJ RB VBP',
#  'NN NN NN JJ NN NN',
#  'NNS DT NN VBZ IN JJS NN MD VB DT JJ NN',
#  'JJ VB IN VBG DT JJ NN NN VBZ NN TO VB .',
#  'NN PRP VBZ IN JJ NN',
#  'NN NN VBD JJS NN NN',
#  'NN NN NN',
#  'NNS WP VBD NN VBD DT NN NN',
#  'RB JJ JJ NNS IN JJ NN WP VBP PRP VB',
#  'NN VB DT NN NN NN WRB VBD PRP VB IN',
#  'JJ JJ NN VB PRP$ NN NN VBZ VBG DT NN',
#  'NN VB PRP$ JJ JJ NN NN VBP NN RB JJ RB VBP NN',
#  'NN IN NN VBZ JJ DT IN PRP NNS VBP TO VB DT IN NN NNS',
#  'IN CD IN PRP VBP VBP DT IN PRP$ NN NN MD VB PRP IN NN NN NN',
#  'JJ NN NNS RP RB JJ NN NN VBD VBD PRP VBD',
#  'NN NN TO VB NN CC NN . NN NN . NN JJ NN . VB JJ NN . NN NNS',
#  'NN IN PRP$ NN VBZ RB JJR IN NN WDT VBZ DT JJ NN NN NN RB',
#  'VBG NN IN JJ VBP NN NN RB JJ',
#  'JJ NN VBD IN DT NNS',
#  'NN NN DT NN NN NN',
#  'VBZ PRP VB IN DT NN',
#  'VB NN RB NNS',
#  'MD VB VB DT JJ NN NN VBP WP VBP VBP NN NN NN',
#  'JJ NN IN PRP$ NN IN DT NN JJ NN RB JJ',
#  'DT RB NN NNS VBP JJ VB WRB JJ NNS',
#  'WRB DT NN NN NN VBP DT JJ NN PRP RB VBP NNS VBP NN',
#  'RB NN NN IN PRP$ NNS VBP VBP JJ PRP$ NNS NN',
#  'NN VBP NN NNS , PRP$ JJ NN VBZ DT NN NN NN NNS VBP',
#  'NN NN',
#  'DT NNS VBP JJ NN',
#  'RB VBN JJ NN PRP RB VB NN PRP VBP VB',
#  'NN VBD IN NN NN NNS VBP NN',
#  'DT DT NN CC RB RB IN DT NN VBZ JJ IN JJ NN PRP$ NNS MD VB JJ NN',
#  'DT NN DT NN VBZ DT NN RB',
#  'NN NN WDT IN DT NN : WP VBZ DT NN',
#  'PDT DT NNS VBP DT NN NN VBP NN VBP DT NN',
#  'CC VB PRP MD VB VBN',
#  'NN NNS IN VBG IN PRP$ JJ NN DT NN PRP MD VB VB RB VBZ DT NN IN DT NN CC NN VBD JJ VBP JJ JJ IN PRP VBP',
#  'JJ NNS IN PDT DT NN NN NN NN RB',
#  'NN DT NN NN NN NN NN PRP VBD PRP$ JJ JJ NN VBG DT NNS VBP VBP JJ VBD JJ VBG DT NN RB VBP PRP VB',
#  'VBN RP NN NN',
#  'NN IN DT NN NN DT JJ NNS',
#  'NNS IN PRP$ NN NN VBP DT NN',
#  'CC VBP VBP DT JJ NN IN VBZ JJR IN PRP MD VB DT NN NN NN RB VBZ IN VB WRB JJ VB VBN JJ',
#  'IN DT NN PRP VBP JJ NN',
#  'NN VBZ VBN NN NNS RB RB DT NN VBZ JJ NNS VBP IN NN NN',
#  'JJ NN PRP VBD VBG NN , JJ VBP VBG DT NN VBZ DT NN',
#  'NNS VBP NN TO PRP$ WP JJ NNS NN',
#  'VB PRP VB DT NNS VBP RB IN NN NN JJ VBP IN NN NNS VBP VBP PRP VBP IN NN DT JJS NN NNS',
#  'NN NN VBP DT RB JJ NN NN VBP DT NN RB',
#  'NN NNS VBP PRP VB PRP VB IN JJ IN DT NN IN PDT DT NNS NN VBP PRP$ JJ NNS IN NN',
#  'NN VBD DT NN PRP VBD PRP VB VBG NNS NN',
#  'NN NN DT VBZ DT NN NNS VBP NN VBZ IN NN',
#  'NN VBD DT NN WDT VBD DT NN VBD DT NN VBG JJ NNS VBP NN',
#  'NN VBP DT NN VB PRP JJ NN CC NN RB VBZ IN PRP$ PRP VBD NNS VBP NN IN PRP WP DT NN DT NN RB',
#  'RB VBP PRP VBD VBG IN NN NNS NN',
#  'NNS VBP PRP VBP JJ NN JJ NN VBZ RB VB PRP NNS NNS VBP JJ VBP NNS VB PRP$ NNS VBP JJ NNS',
#  'NN RB VBD DT NN NN VBP DT NN NN',
#  'NN VBP IN JJ FW NN PRP CC RB VBD DT NN IN PRP$ NNS CC PRP VBP DT NN PRP VBP PRP VBP DT NN WP VBZ PRP VBP',
#  'NN RB VB IN JJR NNS VBP PRP VBP JJR NN WDT VBD TO VB PRP VB',
#  'NN RB VBP RP RP DT NN IN PRP$ NNS IN PRP$ NN CC NN NN IN PRP$ JJ NN',
#  'NN VBD JJ VBP NNS IN NN PRP VBZ IN NN NN VB WRB VB PRP RB VBP WP IN VBZ IN',
#  'NN VBD PRP WRB TO VB NNS CC VB PRP$ JJ NN NN VBD PRP WRB TO VB JJ NN IN DT NN',
#  'NN VBN TO VB RP IN DT NN NN UH NN NN IN JJ NN NN NN NN RB VBD',
#  'JJ VBD TO VB IN DT NN NN VBD RB NN DT NN PRP VBD TO VB IN DT NN VBD RB IN DT NN',
#  'NN MD VB JJ WRB JJ NN . JJ JJ NN . CD JJ NNS JJ NNS VBP VBP DT JJ NN WRB NN VBD RB',
#  'NN VBD RP IN NN NN VBP RB TO NN',
#  'NN MD RB PRP VB PRP VB IN VB PRP$ NN',
#  'NN VBP NN IN DT NN RB JJ',
#  'NN VBP VB PRP$ NN NN',
#  'NN VBP DT JJ NN NN NN NN IN TO VB IN JJ NN NN',
#  'JJ VBP VBG NN TO DT NN',
#  'JJ VBP VBG PRP DT JJ NN CC VBG PRP DT JJ NN PRP VBP JJ VBP RB JJ NN NN VBD VBG IN PRP$ NN NN',
#  'JJ VBP VBP IN NN IN DT NN DT NNS VBD PRP PRP MD VB JJ NN',
#  'JJ VBP JJ NN IN PRP$ JJ NN VBG NNS IN JJ NNS VBP',
#  'NN NN RB PRP$ JJ NN NN VBD NN NN',
#  'JJ VBP NN IN PRP$ NN NN VBD PRP$ NN NN NN NN VBD RP NN NN NN VBD RB DT NN NN',
#  'JJ VBP NN NN VBD JJ NN CC PRP RB VB DT NN',
#  'NN JJ NN NN',
#  'IN PRP VBP PRP$ RB VB RB NN IN PRP VBP VB NN',
#  'IN PRP VBP RB TO PRP PRP VBP JJ VBG DT NN PRP',
#  'IN PRP VBP DT JJ NN VBD PRP$ NNS RB JJ DT NN IN DT NN VBZ VBG EX NNS VBP',
#  'NN NN WDT VBP RP IN DT NN CC JJ NN PRP$ NN IN CD NNS VBD JJ NN NN',
#  'IN PRP$ NN NN VB DT JJ NN NN',
#  'VBZ IN DT NN NN DT NN PRP VBZ NN',
#  'PRP VBZ DT JJ NN TO VB NN PRP VBP WP VB PRP$ NNS IN PRP WDT VBP DT NNS VBP NN',
#  'VBG DT JJ NN IN JJ NN NN JJS TO VB DT NNS JJ TO VB JJ NNS VBN IN NN NN',
#  'VBG PRP$ NN IN NN NNS JJ NNS CC NNS VBP JJ NN',
#  'VB DT NN : RB CD NNS VBG NN IN DT JJ NN',
#  'MD VB NN NN TO DT NN NN NN IN DT NN NN NN VBZ RB DT NN',
#  'PRP VBD NN RP PRP$ JJ NNS VBP JJ NN JJ NN',
#  'PRP VBD JJ NN PRP VBP DT NNS VBP IN',
#  'PRP VBD DT NN RB',
#  'PRP VBD IN NN IN PRP VBP VBN TO VB DT NN NN IN DT JJ NNS',
#  'VB DT NN NN NN NN VBP WRB PRP VBP JJ JJ NN',
#  'RB PRP VBZ DT JJ NN NN PRP RB VBZ IN DT NN',
#  'VB VBG DT NN NN CC VB DT JJ IN PRP$ JJ NN NN',
#  'VB VBG PRP CC VB VB DT NN PRP VBP VB',
#  'VB PRP RB TO VB WRB NN DT NN WRB NN VBP NN MD VB PRP$ NN IN NN',
#  'DT VBP JJ NN NN WDT VBD NN NNS',
#  'DT NN VBZ JJ VBG NN RB JJ NN . NN IN JJS PRP VBZ VBD DT JJ NN VBZ DT JJ NN',
#  'DT NN VBZ IN DT NNS IN DT JJ CC JJ NN NN NN CC JJ NN VBZ RB VBN',
#  'DT NN NN IN NN NN VBP DT JJ NN',
#  'DT NNS VBP JJ NN',
#  'DT NNS VBP NN CC JJ VBP NN NN RP',
#  'DT JJ NN NN NN NN VBP RB JJ NN NN',
#  'PRP VBP NNS RB IN NN VBD RB RB DT NN',
#  'PRP VBP DT JJ NN VBZ VBZ JJ',
#  'PRP VBP NNS DT NN VBZ JJ NNS VBP VB DT JJ NN',
#  'DT VBZ IN PDT DT NNS WDT VBP DT NN NN WDT VBD JJ NNS PRP VBP JJ NN PRP',
#  'DT VBZ IN PRP$ NN NNS VBP NN',
#  'DT NN VBZ IN DT NN NN WP DT NN VBZ DT NN NN WDT VBZ RB DT NN PRP VBP JJ NNS VBP',
#  'DT JJ NNS VBP JJ NN PRP CC PRP$ JJ NN MD VB VB NN IN PRP VBP PRP IN NN NN JJ',
#  'NN JJ NN NN VBP NN',
#  'NN VBZ JJ NN NN VBZ NN',
#  'CD NNS VBN IN DT JJ NN CC NN VBP DT CD TO VB NN NN NN NN',
#  'JJ VBD PRP$ NN NN NN NN NN TO VB NN',
#  'JJ JJ WP VBP PRP VB PRP$ JJ NN PRP$ JJ NN DT JJ NN IN PRP MD VB TO VB NN NN JJS NN VBD JJ NN',
#  'VBN TO VB DT NN RB DT NN VBD VBZ JJ NN VBD VBN IN DT JJ NN CC PRP VBD VBN IN DT NN',
#  'NN NN , JJ NN , JJ NN',
#  'NN NN WDT VBZ WRB JJ NN JJ JJ NNS VBP RB DT VBD DT JJ JJ NNS CC NN NNS',
#  'VBN IN DT NN VBZ IN PRP VBD NN',
#  'PRP VBP IN PRP VBP NNS CC PRP VBP NNS VBP NN',
#  'PRP VBP RP NN CC PRP VBP RB , , , VBP PRP IN PRP IN PRP$ NN',
#  'RB JJ NN NN',
#  'WP VBZ VBP JJ NN PRP IN JJ NN NNS VBP IN PRP$ NN NN RBR IN PRP$ NN',
#  'WRB NN VBN IN DT NN NN VBP PRP TO DT NN NN',
#  'WP DT NN PRP VBP JJ NN',
#  'WRB NNS VBP JJ NN VBZ VBN VBZ IN NN NN JJ VBP NN VBP PRP$ JJ NN VBG NNS VBG RP DT NN VBG NNS DT',
#  'WRB JJ VBG JJ DT JJ NN NN PRP VBP JJ CD NN NNS VBP',
#  'WRB MD VB VBP TO VB IN DT NNS JJ NN',
#  'WRB MD PRP VB VB DT JJ NN PRP VBZ JJ NNS NN',
#  'WRB MD PRP VB NNS IN PRP$ NN NN VBZ DT JJ NN NN',
#  'MD VB DT NN IN NN',
#  'NN VBZ PRP IN DT JJ NNS NN NNS',
#  'NN PRP VBP DT JJ NN WDT VBD RB VBN JJ NN RB PRP VBP TO VB',
#  'RB DT NN PRP VBZ PRP$ NN JJ NN NN IN NN NN DT NNS VBP VBG',
#  'NN VBZ VBD IN PRP$ NN IN DT NN NN NNS VBP PRP$ NNS CC JJ NN VBZ PRP$ NN CC DT JJ NNS VBP',
#  'NN NN NN',
#  'RB NN IN DT NN NN VBP DT NN WDT VBZ JJ NN JJ NN',
#  'NN MD VB VB PRP$ NN NNS',
#  'JJ NNS VBP IN PRP$ NN NN . IN NNS VBP NN',
#  'NN NN NN VBD WP VBD DT CD NN WDT VBD PRP$ NN',
#  'PRP VBP JJ NN VBP VB VB NN',
#  'PRP VBP JJ PRP$ NN VBZ PRP$ JJ NN TO JJ NN',
#  'PRP CC VB VBZ DT JJ NN',
#  'PRP VBP DT NN',
#  'PRP MD VB JJR NN IN DT NN CC VB PRP NNS VBP NN CC NN',
#  'PRP MD VB NN IN IN DT NN CC PRP MD VB VB DT NN IN IN NN',
#  'PRP VBP NNS IN PRP VBD VB WP DT PRP VBZ PRP VBP RB VBN PRP JJ NNS',
#  'PRP VBD NN NNS',
#  'PRP VBP DT JJ DT NN IN NN NN IN IN PRP FW CC VB NN RB IN PRP$ NN PRP VBD DT NN NN',
#  'PRP VBP JJ NN NNP NN NN JJ NN NN',
#  'PRP VBP JJ JJ NNS VBP PRP VB VBN IN DT NN',
#  'PRP VBP IN NN NN NN NN',
#  'PRP VBP IN DT NN CC PRP$ NN JJ NN CC IN JJ JJ NN NN NN IN NNS IN RB VBG JJ JJ NN NN',
#  'PRP VBD PRP$ NN IN PRP MD VB DT JJ VBN IN NN IN PRP$ NN VBZ JJ NN NNS',
#  'PRP VBP DT NN NN CC DT NN VBZ DT NN',
#  'PRP VBP VBN RP DT NN PRP VBP JJ NN RB VBP NN NNS IN PRP$ JJ NN NNS IN NN NN',
#  'PRP$ DT NN .',
#  'PRP$ NN VBG JJ CC PRP VBG NN TO PRP NNS',
#  'PRP$ NNS VBP IN DT NN NN NN NN NN CC RB RB IN DT NN',
#  'JJ NN JJ NN IN NN NN NNS VBP NN NN NN NN',
#  'NN IN PRP NN IN PRP VBP TO VB IN IN RB VBN DT VBZ WP JJ NN NN VBZ TO PRP',
#  'VBP PRP VBP',
#  'NN VBZ JJ IN JJ NN',
#  'NN IN PRP VBP VB DT NN NN NN VBD TO VB RB DT NN',
#  'JJ NN NNS IN JJS JJ NN NNS VBN IN NN NN DT NN JJ NNS VBD VBG NN',
#  'NN NN PRP VBP VBG NN',
#  'NNS IN PRP$ NN',
#  'NN NN NN VBZ DT JJ NN IN NN',
#  'DT NN IN DT NN NN WRB PRP RB VB IN NN CC PRP$ NN VBZ PRP$ NN TO VB',
#  'DT NN IN DT NN NN WRB PRP VBP DT NN IN CC PRP$ JJ NN VBZ IN CC PRP$ DT NN IN DT NN',
#  'DT NN IN DT NN NN WRB PRP$ VBG IN PRP$ NN IN DT NN CC VB PRP$ JJ NN IN DT NN',
#  'NN WRB PRP VBP PRP$ NN VBZ RB CC PRP VBZ IN PRP$ NN CC VBZ IN NN NN VBD IN DT NN',
#  'JJ NNS WP VBP RB JJ CC NN NN NN IN DT NN',
#  'VB WRB TO VB NN IN JJ NNS RB VB NNS',
#  'NN VB PRP$ DT NN NN JJ NN NN VBD JJ NN NN IN JJ NN NN IN NN NN PRP VBZ VBN RB JJ',
#  'NN NN NN VB PRP .',
#  'NN PRP MD VB JJ NNS CC PRP JJR RB VB NN NN',
#  'NN VBD TO NNP IN DT NN NN NN . NN NN',
#  'NNS VBP VBP DT NN NN JJ JJ NN NN NN NN NN NN JJ JJ NN NN',
#  'NN NN VBD RP IN NN',
#  'JJ NN JJ NN NN',
#  'NN MD VB DT NN IN DT NN CC IN DT NN NN VBP PRP VBP NN CC NN . RB RB IN PRP VBP VB DT NN NN',
#  'NN VBZ JJ IN JJ NN',
#  'NN NN NN VBD JJ NN NN JJ NN NN NN VBD NNS NNS VBP',
#  'NN VBZ JJ IN JJ NN',
#  'VBG NN NN VBP NN',
#  'IN DT NNS RB VBD NN IN',
#  'IN PRP MD VB DT NN NN IN TO CD NNS IN DT NN IN TO',
#  'NN NN NN VBZ RB VBG PRP MD VB DT JJ NN NN VBP NN CC VB PRP$ NN NNS VBP',
#  'NNS',
#  'NNS VBP JJ VBP JJ VBP JJ NN',
#  'NNS VBP VB PRP VB DT JJ NN WDT VBZ NN',
#  'NNS VBP NN NN NN VBZ JJ NN NN',
#  'NNS , NNS VBP NNS VB IN NN NN',
#  'NNS . CD JJ NNS IN RB PRP$ NN',
#  'NNS VBP PRP VBP IN DT NN NN IN DT NN NN IN PRP VBP VBG PRP JJ NN',
#  'NNS VBP RB NN WDT NN TO DT JJ RB VB',
#  'NNS VBP VBP JJ VBG IN DT NNS VBP CC JJ NN . PRP VBD JJ JJ NN CC VB DT JJ NN PRP VBD NN',
#  'NNS VBP VBD TO NNS IN NN IN WRB PRP VBD DT JJ DT JJ JJR NN JJ NN RB VBZ NN VBD NNS VBP DT NN NN',
#  'NNS IN NNS VBP DT NN NN NN VBP DT JJ NN VBP NN CC VB DT NN MD VB VB IN IN NN CC NN',
#  'NNS JJ NN RB VBZ NN VB DT NN',
#  'NNS VBP VBN IN . JJ NN',
#  'NNS RB RB VBD NN CC DT NNS VBP IN NNS NNS CC PRP VBP JJ RB JJ NN TO VB JJ NN VB RP NN',
#  'NN IN PRP DT NN DT NN TO VB JJ IN NN NN NN VBP TO VB NN JJR RB DT NN IN NN TO PRP',
#  'NN NN NN NN NN',
#  'NNS PRP$ DT NN NN NN NN',
#  'NN VBZ DT JJ NN NN IN CC IN VBP WRB PRP VBP RB JJ JJ NNS VBP',
#  'NN MD JJ NNS IN PRP VBP DT NN VB DT IN VBG RP VBG VBZ IN DT NNS',
#  'VB PRP VBG DT JJ NN',
#  'NN PRP$ JJ NN NN',
#  'NN TO WRB NN VBN TO VB JJ IN JJ JJ NN',
#  'NN WRB NN VBD PRP$ JJ NN NN',
#  'NN NN IN NNS VBN TO VB JJ NN NN NN NN VBZ JJ FW NN NN RB JJ NN',
#  'NN TO VBG NNS IN NN NNS IN PRP VBD',
#  'NN NN NN IN DT NN IN WP MD RB VB DT JJ NN NN',
#  'JJ PRP$ NN',
#  'JJ NN PRP RB VB RB RP PRP VBP VB PRP RP NN',
#  'JJ NN NN JJ VBZ NNS IN IN IN PRP VBD NN',
#  'NNS VBG DT NN DT NN NN VBZ VBG DT NN NN VBP DT NNS VBP',
#  'NNS NN',
#  'NN NN',
#  'NN PDT DT JJ NNS',
#  'NN NN',
#  'NNS VBP JJ VBP IN DT NN PRP IN DT NN IN DT NN NN VBZ RP PDT DT NN',
#  'JJ NN IN NNS WP VBP IN NN WRB VBP DT NN NN NN',
#  'JJ IN JJ DT JJ NN',
#  'NN TO VB IN DT NN IN NN NN IN DT JJ NN IN DT NN',
#  'NN NNS CC RB NNS IN DT NN NN CC JJ NN VBG RP DT NN TO VB NNS RB IN PRP VBP RB DT NN VBN IN PRP IN NN NN',
#  'NN RP DT NN NN CC NN VBD TO JJ CC VBD PRP CC CD IN PRP$ NN VBD IN NN NN NN',
#  'NN NN NN NN NN VBD DT NN NN NN NN IN NNS',
#  'NN VB DT NN IN NN',
#  'NN NN VBP NN NN RB VBD PRP VBP VB DT NN',
#  'CC NN NN',
#  'NN DT NN IN PRP$ NN NN JJ NN VBD IN JJS CD NN',
#  'PRP$ JJ IN DT JJ NN VBZ DT NN NN',
#  'NN NN NN VBP NN CC PRP DT NN CC JJ VBP NN NN VBZ JJ',
#  'NN DT NN VBD DT NN NN IN VBG NN',
#  'VB DT NN NN NN IN DT RB VBZ RB VB VBG IN NN',
#  'NN DT NNS VBD VBG IN PRP$ JJ JJ JJ NNS',
#  'NNS VBG RB NN .',
#  'RB VBN DT NN VBD RP IN JJ NNS VBP CC RB VBD NN VBD DT NN VBD NNS',
#  'NN NN VBD VBG PRP$ NN VBD PRP$ NN VBG IN DT NN CC PRP RB IN PRP$ NN NN',
#  'JJ NN VBG NNS VBN IN NNS JJ NN',
#  'NN VBZ NN IN PRP VBP VB DT IN DT NN IN DT NNS VBG IN PRP TO VB DT NN',
#  'NN NN VBP RB VB VBN JJR IN DT JJ NN CC DT NN',
#  'NN NN IN DT NNS VBD VBN TO VB JJ NN NNS IN VBG VBN IN DT JJ NN',
#  'NN NN',
#  'VB CD DT NN DT NNS VBP VB RP JJ IN DT NN NN NN WDT VBZ JJ NNS RB JJ JJ NN NN IN DT NN',
#  'NNS PRP VBP VBD DT NN IN DT JJ NN NN VBP JJ WRB PRP$ NNS VBP VBG PRP VBD PRP VBZ NN',
#  'VBD JJ NN NN VBG IN PRP$ NN NN',
#  'NN RB NN IN PRP VBZ PRP IN PRP VBP TO VB VBG NNS IN NN NN PRP VBP IN PRP PRP$ NN',
#  'PRP VBP VB VBG JJ NN',
#  'NN NN NN NN VBD PRP VB NN PRP VB NN NN NN NN RP',
#  'NN VBD RP NN NN VBN IN NN',
#  'JJ PRP$ NN . VB PRP VB NN IN DT NN NN PRP MD VB VBG JJ IN NN IN JJ NN',
#  'NN IN PRP VBP VB DT NN VB IN RP PRP$ NN NN',
#  'IN NN NN VBP PRP VBP IN DT JJ FW PRP$ RB RB JJ NNS VBP WRB PRP VBP DT NN IN PRP$ NN NN JJ',
#  'JJ NN NN IN PRP DT JJ . . . . . NN . NN',
#  'IN DT NN',
#  'NN JJ NN .',
#  'PRP$ NN',
#  'VBZ DT RBS JJ NN PDT DT JJ NN CC VBZ VBZ VBN DT NN NN WDT .',
#  'NN DT NN NNP VBD JJ NN',
#  'NN NN VBG PRP IN PRP$ NN NN NN WDT VBZ RB JJ IN NN NN IN DT NN',
#  'NN NN RB JJ TO VB VBG PRP$ NNS IN NN NN PRP VBP',
#  'NN NN NN IN PRP VBP JJ IN VBG RP JJ NN NN NN JJ IN PRP VB PRP$ NN IN DT NN PRP VBP DT NN',
#  'IN DT NNS RB VB JJ',
#  'NN NN VBZ JJ NNS DT NN IN NNS VBG RP DT JJ IN PRP VBP',
#  'RB DT VBP JJ NN NN NN VBP DT NN IN PRP$ NN NN WRB NN VBP NN PRP IN DT NN',
#  'IN NN NN NN NNS VBP JJ PRP VBZ IN DT NN WP VBD PRP VB .',
#  'PRP$ NN IN NN IN DT NN NN DT DT NN WDT VBZ NN NNS .',
#  'NNS VBP JJ NN',
#  'JJ JJ NN NN TO VB VBN RP',
#  'NN NNS VBP JJ NN VBD PRP VB JJ IN NN VBP VBG NN NN',
#  'NN VBZ PRP IN NN',
#  'RB VBG NNS IN PRP TO PRP NNS IN NN NN NN',
#  'DT JJ NN NN PRP VBZ NN',
#  'NN VBN DT JJ NN NN IN DT JJ JJ NNS',
#  'NN NN NN JJ IN NN NNS',
#  'NN DT NN RB VB FW PRP VBP RB VBP RP IN PRP$ NNS VBP NN NN NN NN VBD RP PRP$ NN NN',
#  'NN WRB DT NN NN JJ IN NN NN NN NN NN NN',
#  'NN NN NN VBP PRP VBD NNS IN PRP$ NN',
#  'VB PRP$ NN',
#  'JJ NN NNS',
#  'NN RB VBD IN NN PRP$ NN NN NN IN DT JJ NN NN NN NN DT NNS VB',
#  'RB IN PRP VBP PRP PRP VBP RB RB VBZ IN DT NN VBP VB',
#  'VBN IN JJ NN NNS VBP RB JJ UH PRP$ NN',
#  'DT NN VB RB JJ NN NN',
#  'NN VBD JJ NN',
#  'JJ VBP NNS VBP NN NN VBZ DT NN NN VBG DT NN IN DT NN NN NN NN',
#  'NN WRB PRP VBP VBG TO VB CC PRP$ NN VBZ VBG RP JJ NNS',
#  'NN VBZ RP RB VBG NNS NN',
#  'NN IN PRP VBP DT NN PRP VBP TO VB PRP VB RB RB',
#  'DT NNS RB JJ JJ NN RB RB TO VB NN',
#  'NN NN IN PRP$ NN NN',
#  'NN NN NN VBD PRP NN',
#  ...]

# %%
#We can use the TFIDF vectorizer to get a token matrix for the POS tags
pos_vectorizer = TfidfVectorizer(
    tokenizer=None,
    lowercase=False,
    preprocessor=None,
    ngram_range=(1, 3),
    stop_words=None,
    use_idf=False,
    smooth_idf=False,
    norm=None,
    decode_error='replace',
    max_features=5000,
    min_df=5,
    max_df=0.75,
    )

# %%
#Construct POS TF matrix and get vocab dict
pos = pos_vectorizer.fit_transform(pd.Series(tweet_tags)).toarray()
pos_vocab = {v:i for i, v in enumerate(pos_vectorizer.get_feature_names())}

# %%
#Now get other features
sentiment_analyzer = VS()

def count_twitter_objs(text_string):
    """
    Accepts a text string and replaces:
    1) urls with URLHERE
    2) lots of whitespace with one instance
    3) mentions with MENTIONHERE
    4) hashtags with HASHTAGHERE

    This allows us to get standardized counts of urls and mentions
    Without caring about specific people mentioned.
    
    Returns counts of urls, mentions, and hashtags.
    """
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    hashtag_regex = '#[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, 'URLHERE', parsed_text)
    parsed_text = re.sub(mention_regex, 'MENTIONHERE', parsed_text)
    parsed_text = re.sub(hashtag_regex, 'HASHTAGHERE', parsed_text)
    return(parsed_text.count('URLHERE'),parsed_text.count('MENTIONHERE'),parsed_text.count('HASHTAGHERE'))

def other_features(tweet):
    """This function takes a string and returns a list of features.
    These include Sentiment scores, Text and Readability scores,
    as well as Twitter specific features"""
    sentiment = sentiment_analyzer.polarity_scores(tweet)
    
    words = preprocess(tweet) #Get text only
    
    syllables = textstat.syllable_count(words)
    num_chars = sum(len(w) for w in words)
    num_chars_total = len(tweet)
    num_terms = len(tweet.split())
    num_words = len(words.split())
    avg_syl = round(float((syllables+0.001))/float(num_words+0.001),4)
    num_unique_terms = len(set(words.split()))
    
    ###Modified FK grade, where avg words per sentence is just num words/1
    FKRA = round(float(0.39 * float(num_words)/1.0) + float(11.8 * avg_syl) - 15.59,1)
    ##Modified FRE score, where sentence fixed to 1
    FRE = round(206.835 - 1.015*(float(num_words)/1.0) - (84.6*float(avg_syl)),2)
    
    twitter_objs = count_twitter_objs(tweet)
    retweet = 0
    if "rt" in words:
        retweet = 1
    features = [FKRA, FRE,syllables, avg_syl, num_chars, num_chars_total, num_terms, num_words,
                num_unique_terms, sentiment['neg'], sentiment['pos'], sentiment['neu'], sentiment['compound'],
                twitter_objs[2], twitter_objs[1],
                twitter_objs[0], retweet]
    #features = pandas.DataFrame(features)
    return features

def get_feature_array(tweets):
    feats=[]
    for t in tweets:
        feats.append(other_features(t))
    return np.array(feats)

# %%
other_features_names = ["FKRA", "FRE","num_syllables", "avg_syl_per_word", "num_chars", "num_chars_total", \
                        "num_terms", "num_words", "num_unique_words", "vader neg","vader pos","vader neu", \
                        "vader compound", "num_hashtags", "num_mentions", "num_urls", "is_retweet"]

# %%
from google.colab import files
uploaded = files.upload()
import io

feats = pd.read_csv(io.StringIO(uploaded['trump_tweets.csv'].decode('utf_8')))
feats
#get_ipython().system(u'pip install textstat')
#feats = get_feature_array(tweets)
# Out:
#      <input type="file" id="files-0f836110-2bbe-47e0-8f4a-91d4f6776685" name="files[]" multiple disabled />
#      <output id="result-0f836110-2bbe-47e0-8f4a-91d4f6776685">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trump_tweets.csv to trump_tweets.csv
# UnicodeDecodeErrorTraceback (most recent call last)
# <ipython-input-49-1f2e221bb7bb> in <module>()
#       3 import io
#       4
# ----> 5 feats = pd.read_csv(io.StringIO(uploaded['trump_tweets.csv'].decode('utf-8')))
#       6 feats
#       7 #!pip install textstat
#
# /usr/lib/python2.7/encodings/utf_8.pyc in decode(input, errors)
#      14
#      15 def decode(input, errors='strict'):
# ---> 16     return codecs.utf_8_decode(input, errors, True)
#      17
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xe5 in position 700: invalid continuation byte

# %%
#Now join them all up
M = np.concatenate([tfidf,pos,feats],axis=1)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-43-576d494f52b7> in <module>()
# ----> 1 M = np.concatenate([tfidf,pos,feats],axis=1)
#
# NameError: name 'feats' is not defined

# %%
M.shape

# %%
#Finally get a list of variable names
variables = ['']*len(vocab)
for k,v in vocab.items():
    variables[v] = k

pos_variables = ['']*len(pos_vocab)
for k,v in pos_vocab.items():
    pos_variables[v] = k

feature_names = variables+pos_variables+other_features_names

# %% [markdown]
# # Running the model
#
# The best model was selected using a GridSearch with 5-fold CV.

# %%
X = pd.DataFrame(M)
y = df['class'].astype(int)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.1)

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(
        [('select', SelectFromModel(LogisticRegression(class_weight='balanced',
                                                  penalty="l1", C=0.01))),
        ('model', LogisticRegression(class_weight='balanced',penalty='l2'))])

# %%
param_grid = [{}] # Optionally add parameters here

# %%
grid_search = GridSearchCV(pipe, 
                           param_grid,
                           cv=StratifiedKFold(n_splits=5, 
                                              random_state=42).split(X_train, y_train), 
                           verbose=2)

# %%
model = grid_search.fit(X_train, y_train)

# %%
y_preds = model.predict(X_test)

# %% [markdown]
# ## Evaluating the results

# %%
report = classification_report( y_test, y_preds )

# %% [markdown]
# ***Note: Results in paper are from best model retrained on the entire dataset (see the other notebook). Here the results are reported after using cross-validation and only for the held-out set.***

# %%
print(report)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_preds)
matrix_proportions = np.zeros((3,3))
for i in range(0,3):
    matrix_proportions[i,:] = confusion_matrix[i,:]/float(confusion_matrix[i,:].sum())
names=['Hate','Offensive','Neither']
confusion_df = pd.DataFrame(matrix_proportions, index=names,columns=names)
plt.figure(figsize=(5,5))
seaborn.heatmap(confusion_df,annot=True,annot_kws={"size": 12},cmap='gist_gray_r',cbar=False, square=True,fmt='.2f')
plt.ylabel(r'True categories',fontsize=14)
plt.xlabel(r'Predicted categories',fontsize=14)
plt.tick_params(labelsize=12)

#Uncomment line below if you want to save the output
#plt.savefig('confusion.pdf')

# %%
#True distribution
y.hist()

# %%
pd.Series(y_preds).hist()
